# %% [markdown]
# # Titanic_naive_bayes

# %% [markdown]
# ### Reading Excel file and making dataset

# %%
import pandas as pd
df=pd.read_csv('titanic_naive_bays.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df=df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis=1)
df
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %%
X=df.drop(['Survived'],axis=1)
Y=df.Survived

# %% [markdown]
# ### One Hot Encoding

# %%
dummy=pd.get_dummies(X.Sex)
dummy
# Out:
#      female  male
# 0         0     1
# 1         1     0
# 2         1     0
# 3         1     0
# 4         0     1
# ..      ...   ...
# 886       0     1
# 887       1     0
# 888       1     0
# 889       0     1
# 890       0     1
#
# [891 rows x 2 columns]

# %%
X=pd.concat([X,dummy],axis=1)
X=X.drop(['Sex'],axis=1)
X
# Out:
#      Pclass   Age     Fare  female  male
# 0         3  22.0   7.2500       0     1
# 1         1  38.0  71.2833       1     0
# 2         3  26.0   7.9250       1     0
# 3         1  35.0  53.1000       1     0
# 4         3  35.0   8.0500       0     1
# ..      ...   ...      ...     ...   ...
# 886       2  27.0  13.0000       0     1
# 887       1  19.0  30.0000       1     0
# 888       3   NaN  23.4500       1     0
# 889       1  26.0  30.0000       0     1
# 890       3  32.0   7.7500       0     1
#
# [891 rows x 5 columns]

# %%
X.isna().sum()
# Out:
# Pclass      0
# Age       177
# Fare        0
# female      0
# male        0
# dtype: int64

# %% [markdown]
# ### Handling Null Values

# %%
X.fillna(X.mean(),inplace=True)

# %% [markdown]
# ### Spliting dataset for training and testing

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=200)

# %% [markdown]
# ### Building Model

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()

# %%
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# ### Scores

# %%
model.score(x_test,y_test)
# Out:
# 0.770949720670391

# %%
model.predict_proba(x_test)
# Out:
# array([[2.34895220e-01, 7.65104780e-01],
#        [9.90904316e-01, 9.09568380e-03],
#        [9.90558345e-01, 9.44165513e-03],
#        [9.89398508e-01, 1.06014923e-02],
#        [2.53731441e-02, 9.74626856e-01],
#        [9.13545393e-01, 8.64546069e-02],
#        [4.02115696e-02, 9.59788430e-01],
#        [9.82519761e-01, 1.74802387e-02],
#        [5.99392570e-02, 9.40060743e-01],
#        [9.87888540e-01, 1.21114597e-02],
#        [9.80749249e-01, 1.92507512e-02],
#        [5.74022324e-02, 9.42597768e-01],
#        [4.96398171e-01, 5.03601829e-01],
#        [1.14928084e-03, 9.98850719e-01],
#        [9.14343712e-01, 8.56562878e-02],
#        [5.77252666e-02, 9.42274733e-01],
#        [9.90118806e-01, 9.88119366e-03],
#        [1.50480724e-03, 9.98495193e-01],
#        [9.79260072e-01, 2.07399279e-02],
#        [9.12013982e-01, 8.79860181e-02],
#        [4.21816823e-02, 9.57818318e-01],
#        [9.90477638e-01, 9.52236183e-03],
#        [2.46217205e-02, 9.75378280e-01],
#        [9.88595340e-01, 1.14046599e-02],
#        [9.70241084e-01, 2.97589157e-02],
#        [9.90524972e-01, 9.47502835e-03],
